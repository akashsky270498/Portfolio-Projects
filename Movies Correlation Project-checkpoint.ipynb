# %%
#Importing Modules
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we create

#Reading the CSV Data File
df = pd.read_csv('D:\ADataSet\Portfolio\My Portfolio\Python\movies1.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#         released  score    votes         director                   writer  \
# 0  Jun 13, 1980     8.4   927000  Stanley Kubrick             Stephen King
# 1   Jul 2, 1980     5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2  Jun 20, 1980     8.7  1200000   Irvin Kershner           Leigh Brackett
# 3   Jul 2, 1980     7.7   221000     Jim Abrahams             Jim Abrahams
# 4  Jul 25, 1980     7.3   108000     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
#Looking the missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}-->{}%'.format(col,pct_missing))
# Out:
# name-->0.0%
# rating-->0.0%
# genre-->0.0%
# year-->0.0%
# released-->0.0%
# score-->0.0%
# votes-->0.0%
# director-->0.0%
# writer-->0.0%
# star-->0.0%
# country-->0.0%
# budget-->0.0%
# gross-->0.0%
# company-->0.0%
# runtime-->0.0%

# %%
#Datatypes of columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %%
#Changing the datatypes of Columns

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7663                                    More to Life  Not Rated      Drama
# 7664                                     Dream Round  Not Rated     Comedy
# 7665                                   Saving Mbango  Not Rated      Drama
# 7666                                    It's Just Us  Not Rated      Drama
# 7667                                       Tee em el  Not Rated     Horror
#
#       year       released  score    votes         director  \
# ...

# %%
#Correcting the Year
df['yearcorrect'] = df['released'].astype(str).str[7:]

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7663                                    More to Life  Not Rated      Drama
# 7664                                     Dream Round  Not Rated     Comedy
# 7665                                   Saving Mbango  Not Rated      Drama
# 7666                                    It's Just Us  Not Rated      Drama
# 7667                                       Tee em el  Not Rated     Horror
#
#       year       released  score    votes         director  \
# ...

# %%
df = df.sort_values(by=['gross'],inplace=False,ascending=False)

# %%
#Dropping Duplicates
df['company'].drop_duplicates
# Out:
# <bound method Series.drop_duplicates of 27                                   ITC Films
# 91                      East Asia Film Company
# 79                      Santa Fe International
# 5445                     Twentieth Century Fox
# 7445                            Marvel Studios
#                          ...
# 3818    British Broadcasting Corporation (BBC)
# 7625                 Visual Arts Entertainment
# 7580                             Roxwell Films
# 2417            DENTSU Music And Entertainment
# 3203                                  Daybreak
# Name: company, Length: 7668, dtype: object>

# %%
#Budget Data Corelation
#Gross Data Corelation

plt.scatter(x = df['budget'], y = df['gross'])

plt.title('Budget v/s Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Films')
plt.show()

# %%
df.head()
# Out:
#                      name     rating      genre  year       released  score  \
# 27      Raise the Titanic         PG     Action  1980   Aug 1, 1980     5.0
# 91    Mantis Fist Fighter  Not Rated     Action  1980   Jul 9, 1982     6.7
# 79             Windwalker         PG  Adventure  1980  Nov 18, 1983     6.9
# 5445               Avatar      PG-13     Action  2009  Dec 18, 2009     7.8
# 7445    Avengers: Endgame      PG-13     Action  2019  Apr 26, 2019     8.4
#
#         votes       director              writer               star  \
# 27       4100  Jerry Jameson        Adam Kennedy      Jason Robards
# 91        230   Wing-Cho Yip       Hsin-Yi Chang       Ka-Yan Leung
# 79       1000  Kieth Merrill         Ray Goldrup      Trevor Howard
# 5445  1100000  James Cameron       James Cameron    Sam Worthington
# 7445   903000  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#              country     budget       gross                 company  runtime  \
# ...

# %%
#Regression Plot of Budget v/s Gross using seaborn

sns.regplot(x='budget', y='gross', data=df)
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Adding Colour to Line
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"black"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Lets start lokking on the Correlation (Correlation works only on numerical data)

# %%
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.096265  0.222686  0.352338  0.219004  0.121452
# score    0.096265  1.000000  0.407845  0.057097  0.164858  0.397664
# votes    0.222686  0.407845  1.000000  0.478574  0.572475  0.308849
# budget   0.352338  0.057097  0.478574  1.000000  0.676106  0.256915
# gross    0.219004  0.164858  0.572475  0.676106  1.000000  0.220571
# runtime  0.121452  0.397664  0.308849  0.256915  0.220571  1.000000

# %%
#Differbnt types of Correlations are:-
#pearson,kendall,spearman

# %%
df.corr(method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.098540  0.469639  0.504087  0.283280  0.143663
# score    0.098540  1.000000  0.427282  0.018341  0.119868  0.398820
# votes    0.469639  0.427282  1.000000  0.570662  0.708260  0.289731
# budget   0.504087  0.018341  0.570662  1.000000  0.583477  0.236195
# gross    0.283280  0.119868  0.708260  0.583477  1.000000  0.235002
# runtime  0.143663  0.398820  0.289731  0.236195  0.235002  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067332  0.331309  0.358666  0.193692  0.097652
# score    0.067332  1.000000  0.299502  0.012725  0.081694  0.282855
# votes    0.331309  0.299502  1.000000  0.415806  0.520346  0.197950
# budget   0.358666  0.012725  0.415806  1.000000  0.425245  0.165496
# gross    0.193692  0.081694  0.520346  0.425245  1.000000  0.160743
# runtime  0.097652  0.282855  0.197950  0.165496  0.160743  1.000000

# %%
df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.096265  0.222686  0.352338  0.219004  0.121452
# score    0.096265  1.000000  0.407845  0.057097  0.164858  0.397664
# votes    0.222686  0.407845  1.000000  0.478574  0.572475  0.308849
# budget   0.352338  0.057097  0.478574  1.000000  0.676106  0.256915
# gross    0.219004  0.164858  0.572475  0.676106  1.000000  0.220571
# runtime  0.121452  0.397664  0.308849  0.256915  0.220571  1.000000

# %%
#High Correlation between Budget and Gross

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matrix for Numeric Feature')
plt.xlabel('Movies Features')
plt.ylabel('Movies Features')

plt.show()

# %%
#Lets see the Company 
df.head()
# Out:
#                      name     rating      genre  year       released  score  \
# 27      Raise the Titanic         PG     Action  1980   Aug 1, 1980     5.0
# 91    Mantis Fist Fighter  Not Rated     Action  1980   Jul 9, 1982     6.7
# 79             Windwalker         PG  Adventure  1980  Nov 18, 1983     6.9
# 5445               Avatar      PG-13     Action  2009  Dec 18, 2009     7.8
# 7445    Avengers: Endgame      PG-13     Action  2019  Apr 26, 2019     8.4
#
#         votes       director              writer               star  \
# 27       4100  Jerry Jameson        Adam Kennedy      Jason Robards
# 91        230   Wing-Cho Yip       Hsin-Yi Chang       Ka-Yan Leung
# 79       1000  Kieth Merrill         Ray Goldrup      Trevor Howard
# 5445  1100000  James Cameron       James Cameron    Sam Worthington
# 7445   903000  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#              country     budget       gross                 company  runtime  \
# ...

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
       df_numerized[col_name] = df_numerized[col_name].astype('category')
       df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 27    4442       4      0  1980       235    5.0     4100      1282      33
# 91    3474       3      0  1980      1451    6.7      230      2907    1674
# 79    7384       4      1  1980      2273    6.9     1000      1618    3492
# 5445   533       5      0  2009       601    7.8  1100000      1155    1780
# 7445   535       5      0  2019       144    8.4   903000       162     743
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 3818  3360       6      4  2000       975    6.5     5200       730    1124
# 7625  6720       3      4  2019      1003    5.7      320      2546    2567
# 7580  4664       3      5  2019      1613    5.2      735      1445    2205
# 2417  3406       3      6  1993        65    7.3     5100        33    1720
# 3203  6990       5      4  1997      2444    5.7     5800       961     229
#
# ...

# %%
df
# Out:
#                       name     rating      genre  year       released  score  \
# 27       Raise the Titanic         PG     Action  1980   Aug 1, 1980     5.0
# 91     Mantis Fist Fighter  Not Rated     Action  1980   Jul 9, 1982     6.7
# 79              Windwalker         PG  Adventure  1980  Nov 18, 1983     6.9
# 5445                Avatar      PG-13     Action  2009  Dec 18, 2009     7.8
# 7445     Avengers: Endgame      PG-13     Action  2019  Apr 26, 2019     8.4
# ...                    ...        ...        ...   ...            ...    ...
# 3818  Love, Honor and Obey          R     Comedy  2000   Feb 9, 2001     6.5
# 7625      The Untold Story  Not Rated     Comedy  2019  Jan 11, 2019     5.7
# 7580   Run with the Hunted  Not Rated      Crime  2019  Jun 26, 2020     5.2
# 2417              Madadayo  Not Rated      Drama  1993  Apr 17, 1993     7.3
# 3203            Trojan War      PG-13     Comedy  1997   Oct 1, 1997     5.7
#
# ...

# %%
#Correlation Heatmap for all Columns

correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matrix for Numeric Feature')
plt.xlabel('Movies Features')
plt.ylabel('Movies Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.010860  0.016355  0.011453 -0.009933  0.016405
# rating      -0.010860  1.000000  0.104108  0.019913  0.020917  0.006622
# genre        0.016355  0.104108  1.000000 -0.081261  0.031071  0.028249
# year         0.011453  0.019913 -0.081261  1.000000 -0.002797  0.096265
# released    -0.009933  0.020917  0.031071 -0.002797  1.000000  0.042465
# score        0.016405  0.006622  0.028249  0.096265  0.042465  1.000000
# votes        0.013110  0.022933 -0.145328  0.222686  0.015987  0.407845
# director     0.009079  0.018466 -0.015258 -0.020795 -0.001580  0.009822
# writer       0.009703 -0.005607  0.006612 -0.008138 -0.003521  0.021184
# star         0.006734  0.008716 -0.004889 -0.027715  0.013497 -0.001195
# country     -0.010425  0.053305 -0.035896 -0.069423 -0.023780 -0.134530
# budget       0.022294 -0.112938 -0.318549  0.352338  0.009537  0.057097
# ...

# %%
Correlation_mat = df_numerized.corr()

corr_pairs = Correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.010860
#              genre          0.016355
#              year           0.011453
#              released      -0.009933
#                               ...
# yearcorrect  budget         0.185189
#              gross          0.122816
#              company       -0.004325
#              runtime        0.051113
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.318549
# budget       genre         -0.318549
# genre        gross         -0.220814
# gross        genre         -0.220814
# votes        genre         -0.145328
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
High_corr = sorted_pairs[(sorted_pairs) > 0.5]
High_corr
# Out:
# year         yearcorrect    0.553260
# yearcorrect  year           0.553260
# gross        votes          0.572475
# votes        gross          0.572475
# budget       gross          0.676106
# gross        budget         0.676106
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64
